# %% [markdown]
# <a href="https://colab.research.google.com/github/yyoma/xai-ids-baselines/blob/main/ADA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the missing InterpretML library inside Colab's temporary environment
# !pip install interpret

# %%
# ==========================================
# STEP 2: DOWNLOAD THE DATASETS (BUG FIX FOR PYTHON 3.13)
# ==========================================
import os
import kagglehub
from google.colab import userdata

# Retrieve the token from secrets and strip out any hidden newline characters (\r\n)
raw_token = userdata.get("KAGGLE_API_TOKEN")
clean_token = raw_token.strip() if raw_token else ""

# Set the environment variable with the clean token
os.environ["KAGGLE_API_TOKEN"] = clean_token


# 2. Download RoEduNet-SIMARGL2021
print("📥 Downloading RoEduNet-SIMARGL2021...")
simargl_path = kagglehub.dataset_download("h2020simargl/simargl2022")
print(f"✅ RoEduNet-SIMARGL2022 downloaded to: {simargl_path}")
# Out:
# 📥 Downloading RoEduNet-SIMARGL2021...
# Downloading to /root/.cache/kagglehub/datasets/h2020simargl/simargl2022/1.archive...
# 100%|██████████| 613M/613M [00:07<00:00, 85.5MB/s]
# Extracting files...
# ✅ RoEduNet-SIMARGL2022 downloaded to: /root/.cache/kagglehub/datasets/h2020simargl/simargl2022/versions/1

# %%
# ==========================================
# STEP 2: RE-LINK THE 'sensor_db' SHORTCUT
# ==========================================
import os

# Define the correct path to the 2022 dataset we just downloaded
simargl2022_path = "/root/.cache/kagglehub/datasets/h2020simargl/simargl2022/versions/1"

# Delete the old shortcut if it exists
if os.path.exists("sensor_db"):
    os.remove("sensor_db")
    print("Removing old 'sensor_db' shortcut...")

# Create the new shortcut pointing to the 2022 folder
os.symlink(simargl2022_path, "sensor_db")
print("✅ Successfully linked 'sensor_db' to your 2022 Kaggle dataset!")
# Out:
# Removing old 'sensor_db' shortcut...
# ✅ Successfully linked 'sensor_db' to your 2022 Kaggle dataset!

# %%
#A ==========================================
# STEP 3: RUN THE TRAINING PIPELINE
# ==========================================
# This tells python to execute your script, feeding it the exact path where SIMARGL was downloaded.

# !python3 "/content/drive/MyDrive/ADA_SML.py"
# Out:
#             FLOW_ID  L4_SRC_PORT  L4_DST_PORT  ...  OUT_PKTS  ALERT  is_train
# 15701418  351287163        58733          443  ...      1537      1      True
# 28713869  340225984        47460        57754  ...         1      2      True
# 12050533  351843229            0            0  ...         0      1      True
# 9142336   340376147          443        50960  ...         1      1      True
# 25820634  374223027        41374           53  ...         1      1      True
#
# [5 rows x 28 columns]
# Number of the training data: 1055356
# Number of the testing data: 452028
# ---------------------------------------------------------------------------------
# Balance Datasets
# ---------------------------------------------------------------------------------
#
# Counter({1: 684023, 0: 225664, 2: 145481})
# train len Counter({1: 684023, 0: 684023, 2: 684023})
# Counter({1: 293265, 0: 96198, 2: 62753})
# test len  Counter({1: 293265, 0: 293265, 2: 293265})
# ELAPSE TIME MODEL:  4.488636596997579 min
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
# ELAPSE TIME PREDICTION:  0.03496899207433065 min
# ---------------------------------------------------------------------------------
# Generating Confusion Matrix
# ---------------------------------------------------------------------------------
#
# Predicted ALERT      0       1      2
# Actual ALERT
# 0                96017     173      0
# 1                44424  225403  23169
# 2                    0      21  62821
# Accuracy:  0.9000253671601465
# Precision:  0.8500380507402197
# Recall:  0.8500380507402197
# F1:  0.8500380507402197
# BACC:  0.8875285380551647
# MCC:  0.7750570761103295
# Accuracy for Denial of Service - 0.9013401824665729
# Accuracy for Normal - 0.8500380507402197
# Accuracy for Port Scanning - 0.9486978682736468
# AUC_ROC total:  0.9937662716871788
