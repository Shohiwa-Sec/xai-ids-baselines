# %% [markdown]
# <a href="https://colab.research.google.com/github/yyoma/xai-ids-baselines/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the missing InterpretML library inside Colab's temporary environment
# !pip install interpret

# %%
# ==========================================
# STEP 2: DOWNLOAD THE DATASETS (BUG FIX FOR PYTHON 3.13)
# ==========================================
import os
import kagglehub
from google.colab import userdata

# Retrieve the token from secrets and strip out any hidden newline characters (\r\n)
raw_token = userdata.get("KAGGLE_API_TOKEN")
clean_token = raw_token.strip() if raw_token else ""

# Set the environment variable with the clean token
os.environ["KAGGLE_API_TOKEN"] = clean_token


# 2. Download RoEduNet-SIMARGL2021
print("📥 Downloading RoEduNet-SIMARGL2021...")
simargl_path = kagglehub.dataset_download("h2020simargl/simargl2022")
print(f"✅ RoEduNet-SIMARGL2022 downloaded to: {simargl_path}")
# Out:
# 📥 Downloading RoEduNet-SIMARGL2021...
# Downloading to /root/.cache/kagglehub/datasets/h2020simargl/simargl2022/1.archive...
# 100%|██████████| 613M/613M [00:29<00:00, 21.5MB/s]
# Extracting files...
# ✅ RoEduNet-SIMARGL2022 downloaded to: /root/.cache/kagglehub/datasets/h2020simargl/simargl2022/versions/1

# %%
# ==========================================
# STEP 2: RE-LINK THE 'sensor_db' SHORTCUT
# ==========================================
import os

# Define the correct path to the 2022 dataset we just downloaded
simargl2022_path = "/root/.cache/kagglehub/datasets/h2020simargl/simargl2022/versions/1"

# Delete the old shortcut if it exists
if os.path.exists("sensor_db"):
    os.remove("sensor_db")
    print("Removing old 'sensor_db' shortcut...")

# Create the new shortcut pointing to the 2022 folder
os.symlink(simargl2022_path, "sensor_db")
print("✅ Successfully linked 'sensor_db' to your 2022 Kaggle dataset!")
# Out:
# ✅ Successfully linked 'sensor_db' to your 2022 Kaggle dataset!

# %%
# !pip install lime

# %%
#A ==========================================
# STEP 3: RUN THE TRAINING PIPELINE
# ==========================================
# This tells python to execute your script, feeding it the exact path where SIMARGL was downloaded.

# !python3 "/content/drive/MyDrive/KNN_SML.py"
# Out:
# ---------------------------------------------------------------------------------
# KNN
# ---------------------------------------------------------------------------------
# Importing libraries
# ---------------------------------------------------------------------------------
# 2026-09-12 22:17:02.700142: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-09-12 22:17:02.741774: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------------
# Defining Metrics
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Defining features
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# loading databases
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Normalizing Databases
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Spliting the db in training and testing
# ---------------------------------------------------------------------------------
# Number of the training data: 210849
# Number of the testing data: 90628
# y_train:  [0 1 0 ... 0 0 0]
# y_test:  [0 1 1 ... 0 0 0]
# ---------------------------------------------------------------------------------
# Balance Datasets
# ---------------------------------------------------------------------------------
#
# Counter({'nan': 136781, 'Denial of Service': 45200, 'Port Scanning': 29052})
# train len Counter({'Port Scanning': 136781, 'Denial of Service': 136781, 'nan': 136781})
# Counter({'nan': 58802, 'Denial of Service': 19275, 'Port Scanning': 12367})
# test len  Counter({'nan': 58802, 'Denial of Service': 58802, 'Port Scanning': 58802})
# ---------------------------------------------------------------------------------
# Defining KNN Model
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# Training Model
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# ELAPSE TIME MODEL TRAINING:  0.017664245764414468 min
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# ELAPSE TIME MODEL PREDICTION:  1.0902467290560405 min
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# CONFUSION MATRIX
# ---------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------
# METRICS
# ---------------------------------------------------------------------------------
# Precision total:  0.9984410961078422
# Recall total:  0.9984410961078422
# F1 total:  0.9984410961078422
# BACC total:  0.9988308220808816
# MCC total:  0.9976616441617632
# startAUCROC
# /usr/local/lib/python3.13/dist-packages/sklearn/neighbors/_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ok
# /usr/local/lib/python3.13/dist-packages/sklearn/neighbors/_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ok
# /usr/local/lib/python3.13/dist-packages/sklearn/neighbors/_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ok
# AUC ROC Average: 0.9987884539591579
# /content/drive/MyDrive/KNN_SML.py:651: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Acc = ACC(TP[i],TN[i], FP[i], FN[i])
# Accuracy:  Port Scanning  -  0.9994501320816752
# Accuracy:  Denial of Service  -  0.9989909640261669
# Accuracy:  nan  -  0.9984410961078422
