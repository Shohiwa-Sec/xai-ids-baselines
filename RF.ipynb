# %% [markdown]
# <a href="https://colab.research.google.com/github/yyoma/xai-ids-baselines/blob/main/RF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the missing InterpretML library inside Colab's temporary environment
# !pip install interpret
# Out:
# Collecting interpret
#   Downloading interpret-0.7.8-py3-none-any.whl.metadata (1.2 kB)
# Collecting interpret-core==0.7.8 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret)
#   Downloading interpret_core-0.7.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.13/dist-packages (from interpret-core==0.7.8->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2.1.3)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.13/dist-packages (from interpret-core==0.7.8->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from interpret-core==0.7.8->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.6.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.13/dist-packages (from interpret-core==0.7.8->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.6.0)
# Requirement already satisfied: psutil>=5.6.2 in /usr/local/lib/python3.13/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (5.9.5)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.13/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (7.34.0)
# Requirement already satisfied: plotly>=3.8.1 in /usr/local/lib/python3.13/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (5.24.1)
# Collecting SALib>=1.3.3 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret)
#   Downloading salib-1.5.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: shap>=0.28.5 in /usr/local/lib/python3.13/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.52.0)
# Requirement already satisfied: ipywidgets>=7.4.2 in /usr/local/lib/python3.13/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (7.7.1)
# Collecting aplr>=10.6.1 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret)
#   Downloading aplr-10.26.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.1 kB)
# Collecting dash>=2.0.0 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret)
#   Downloading dash-4.4.1-py3-none-any.whl.metadata (11 kB)
# Collecting dash-cytoscape>=0.1.1 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret)
#   Downloading dash_cytoscape-1.0.2.tar.gz (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: flask>=1.0.4 in /usr/local/lib/python3.13/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.1.3)
# Collecting gevent>=1.3.6 (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret)
#   Downloading gevent-26.8.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.13/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2.32.4)
# Requirement already satisfied: Werkzeug<3.2 in /usr/local/lib/python3.13/dist-packages (from dash>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.1.8)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.13/dist-packages (from dash>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (9.0.1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.13/dist-packages (from dash>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (4.16.0)
# Collecting retrying (from dash>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.13/dist-packages (from dash>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from dash>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (80.10.2)
# Collecting janus>=1.0.0 (from dash>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret)
#   Downloading janus-2.0.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pydantic>=2.10 in /usr/local/lib/python3.13/dist-packages (from dash>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2.13.5)
# Collecting comm (from dash>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from flask>=1.0.4->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.13/dist-packages (from flask>=1.0.4->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (8.5.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from flask>=1.0.4->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.13/dist-packages (from flask>=1.0.4->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from flask>=1.0.4->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.0.3)
# Requirement already satisfied: greenlet>=3.2.2 in /usr/local/lib/python3.13/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.5.5)
# Collecting zope.event (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret)
#   Downloading zope_event-6.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting zope.interface (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret)
#   Downloading zope_interface-8.6-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 3.3 MB/s eta 0:00:00
# Collecting jedi>=0.16 (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.13/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.13/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.13/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.0.53)
# Requirement already satisfied: pygments in /usr/local/lib/python3.13/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2.21.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.13/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.13/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.13/dist-packages (from ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.13/dist-packages (from ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.0.17)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=0.11->interpret-core==0.7.8->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=0.24->interpret-core==0.7.8->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=0.24->interpret-core==0.7.8->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=0.24->interpret-core==0.7.8->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2026.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.13/dist-packages (from plotly>=3.8.1->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (9.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from plotly>=3.8.1->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (26.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2026.7.22)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.13/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.10.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.13/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.70.19)
# Requirement already satisfied: scipy>=1.9.3 in /usr/local/lib/python3.13/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.6.0->interpret-core==0.7.8->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.6.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.13/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (4.67.3)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.13/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.13/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.61.2)
# Requirement already satisfied: llvmlite in /usr/local/lib/python3.13/dist-packages (from shap>=0.28.5->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.44.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (7.4.9)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.13/dist-packages (from jedi>=0.16->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.8.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.5.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.5->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.3.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.13/dist-packages (from pexpect>4.3->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.7.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.13/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.8.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.10->dash>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.10->dash>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.10->dash>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.4.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24->interpret-core==0.7.8->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.17.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.13/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (6.5.7)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.13/dist-packages (from importlib-metadata->dash>=2.0.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (4.1.0)
# Requirement already satisfied: dill>=0.4.1 in /usr/local/lib/python3.13/dist-packages (from multiprocess->SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.4.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.13/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.13/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (5.9.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (5.11.1)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (7.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.26.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.3.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.13/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (4.11.7)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.13/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.3.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.13/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2.22.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.13/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.13/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (26.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.13/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.6.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2026.6.3)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.13/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2.20.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2.1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (2.9.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (4.14.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.5.4)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.9.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (4.2.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.13/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.13/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.4.2->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.7.8->interpret) (1.4.0)
# Downloading interpret-0.7.8-py3-none-any.whl (1.4 kB)
# Downloading interpret_core-0.7.8-py3-none-any.whl (15.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 60.7 MB/s eta 0:00:00
# Downloading aplr-10.26.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 64.7 MB/s eta 0:00:00
# Downloading dash-4.4.1-py3-none-any.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 76.0 MB/s eta 0:00:00
# Downloading gevent-26.8.0-cp313-cp313-manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 94.5 MB/s eta 0:00:00
# Downloading salib-1.5.2-py3-none-any.whl (780 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.1/780.1 kB 34.0 MB/s eta 0:00:00
# Downloading janus-2.0.0-py3-none-any.whl (12 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 73.9 MB/s eta 0:00:00
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading zope_event-6.2-py3-none-any.whl (6.5 kB)
# Downloading zope_interface-8.6-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (270 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.6/270.6 kB 21.4 MB/s eta 0:00:00
# Building wheels for collected packages: dash-cytoscape
#   Building wheel for dash-cytoscape (setup.py) ... done
#   Created wheel for dash-cytoscape: filename=dash_cytoscape-1.0.2-py3-none-any.whl size=4010811 sha256=06c524fb056dfde7883746b5cf1d487e0d8c066c65018c06007ead0235d885e1
#   Stored in directory: /root/.cache/pip/wheels/1d/3a/14/e8bdf175039d5a4597973c9c04e7ba2d4d77420c62a1fc7c0d
# Successfully built dash-cytoscape
# Installing collected packages: zope.interface, zope.event, retrying, jedi, janus, comm, gevent, SALib, interpret-core, dash, aplr, dash-cytoscape, interpret
# Successfully installed SALib-1.5.2 aplr-10.26.0 comm-0.2.3 dash-4.4.1 dash-cytoscape-1.0.2 gevent-26.8.0 interpret-0.7.8 interpret-core-0.7.8 janus-2.0.0 jedi-0.20.0 retrying-1.4.2 zope.event-6.2 zope.interface-8.6

# %%
# ==========================================
# STEP 2: DOWNLOAD THE DATASETS (BUG FIX FOR PYTHON 3.13)
# ==========================================
import os
import kagglehub
from google.colab import userdata

# Retrieve the token from secrets and strip out any hidden newline characters (\r\n)
raw_token = userdata.get("KAGGLE_API_TOKEN")
clean_token = raw_token.strip() if raw_token else ""

# Set the environment variable with the clean token
os.environ["KAGGLE_API_TOKEN"] = clean_token


# 2. Download RoEduNet-SIMARGL2021
print("📥 Downloading RoEduNet-SIMARGL2021...")
simargl_path = kagglehub.dataset_download("h2020simargl/simargl2022")
print(f"✅ RoEduNet-SIMARGL2022 downloaded to: {simargl_path}")
# Out:
# 📥 Downloading RoEduNet-SIMARGL2021...
# Downloading to /root/.cache/kagglehub/datasets/h2020simargl/simargl2022/1.archive...
# 100%|██████████| 613M/613M [00:26<00:00, 24.2MB/s]
# Extracting files...
# ✅ RoEduNet-SIMARGL2022 downloaded to: /root/.cache/kagglehub/datasets/h2020simargl/simargl2022/versions/1

# %%
# ==========================================
# STEP 2: RE-LINK THE 'sensor_db' SHORTCUT
# ==========================================
import os

# Define the correct path to the 2022 dataset we just downloaded
simargl2022_path = "/root/.cache/kagglehub/datasets/h2020simargl/simargl2022/versions/1"

# Delete the old shortcut if it exists
if os.path.exists("sensor_db"):
    os.remove("sensor_db")
    print("Removing old 'sensor_db' shortcut...")

# Create the new shortcut pointing to the 2022 folder
os.symlink(simargl2022_path, "sensor_db")
print("✅ Successfully linked 'sensor_db' to your 2022 Kaggle dataset!")
# Out:
# ✅ Successfully linked 'sensor_db' to your 2022 Kaggle dataset!

# %%
#A ==========================================
# STEP 3: RUN THE TRAINING PIPELINE
# ==========================================
# This tells python to execute your script, feeding it the exact path where SIMARGL was downloaded.

# !python3 "/content/drive/MyDrive/RF_SML.py"
# Out:
# --------------------------------------------------
# RF
# --------------------------------------------------
# Importing Libraries
# --------------------------------------------------
# <IPython.core.display.HTML object>
# Defining Function
# --------------------------------------------------
# Selecting Column Features
# --------------------------------------------------
# Loading Database
# --------------------------------------------------
# ---------------------------------------------------------------------------------
# Normalizing database
# ---------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------
# Counting labels
# ---------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------
# Balance Datasets
# ---------------------------------------------------------------------------------
#
# Counter({'nan': 5978624, 'Denial of Service': 2023479, 'Port Scanning': 1459694})
# Using class-weighted training; no training rows are duplicated.
# Defining the model
# --------------------------------------------------
# Training the model
# ------------------------------------------------------------------------------
# ELAPSE TIME MODEL:  3.303795611858368 min
# ------------------------------------------------------------------------------
# Counter({'nan': 2562267, 'Denial of Service': 867205, 'Port Scanning': 625584})
# ELAPSE TIME PREDICTION:  0.026314274470011393 min
# ------------------------------------------------------------------------------
# Predicted ALERT    Denial of Service  Port Scanning      nan
# Actual ALERT
# Denial of Service             867205              0        0
# Port Scanning                      0         625467      117
# nan                              387           2157  2559723
#
# Per-class precision, recall, and F1:
#                    precision    recall  f1-score   support
#
# Denial of Service     0.9996    1.0000    0.9998    867205
#     Port Scanning     0.9966    0.9998    0.9982    625584
#               nan     1.0000    0.9990    0.9995   2562267
#
#          accuracy                         0.9993   4055056
#         macro avg     0.9987    0.9996    0.9991   4055056
#      weighted avg     0.9993    0.9993    0.9993   4055056
#
# Accuracy:  0.9995625214546976
# Precision:  0.9993437821820463
# Recall:  0.9993437821820463
# F1:  0.9993437821820463
# BACC:  0.9995078366365348
# MCC:  0.9990156732730695
# /content/drive/MyDrive/RF_SML.py:540: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Acc = ACC(TP[i],TN[i], FP[i], FN[i])
# Accuracy:  nan  -  0.9999045635867914
# Accuracy:  Port Scanning  -  0.9994392185952549
# Accuracy:  Denial of Service  -  0.9993437821820463
# AUC_ROC total:  0.9999965834852401
